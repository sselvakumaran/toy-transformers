# %%
import sys
import os 

sys.path.append("..")
from toy_transformers.utilities import io
import torch

# %%
tensor = torch.tensor([1, 2, 3, 4, 5], device="mps")

state_dict = {
	"vocab_size": 513,
	"device": "mps",
	"data": {
		"tensor": io.TorchTensorRef("data.pt", tensor)
  }
}

# %%
X, Y = io.encode(state_dict)
X, Y
# Out:
# ({'vocab_size': 513,
#   'device': 'mps',
#   'data': {'tensor': {'__type__': 'TorchTensorRef', '__ref__': 'data.pt'}}},
#  [TorchTensorRef(name='data.pt', tensor=tensor([1, 2, 3, 4, 5], device='mps:0'))])

# %%
io.decode(X)
# Out:
# ({'vocab_size': 513,
#   'device': 'mps',
#   'data': {'tensor': TorchTensorRef(name='data.pt', tensor=None)}},
#  [TorchTensorRef(name='data.pt', tensor=None)])

# %%
io.save(state_dict, path="temp/epic1")

# %%
A = io.load("temp/epic1")
A
# Out:
# {'vocab_size': 513,
#  'device': 'mps',
#  'data': {'tensor': TorchTensorRef(name='data.pt', tensor=tensor([1, 2, 3, 4, 5], device='mps:0'))}}
