# %%
import sys
import os
from tqdm import tqdm

sys.path.append(os.path.abspath(os.path.join('..')))

from utilities.loss_plotter import LossTracker

# %%
import time
import random
from IPython.display import display, clear_output
plotter = LossTracker(palette="deep")

# %%
for i in range(1000):
  train_loss = 1 / (i + 1) + random.uniform(0, 0.05)
  val_loss = 1 / (i + 2) + random.uniform(0, 0.05) if i % 10 == 0 else None
  plotter.add_points(train_loss, val_loss)
  if i % 1 == 0:
    fig = plotter.render_fast_figure()
    display(fig, clear=True)
  # time.sleep(0.05)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 if i % 1 == 0:
#       6   fig = plotter.render_fast_figure()
# ----> 7   display(fig, clear=True)
#       8 # time.sleep(0.05)
#
# File ~/dev/apps/toy-gpt/venv/lib/python3.11/site-packages/IPython/core/display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~/dev/apps/toy-gpt/venv/lib/python3.11/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# ...
